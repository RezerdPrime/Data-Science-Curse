# %% [markdown]
# ## Практическая работа

# %% [markdown]
# В этой практической работе четыре обязательные задачи.
#
# *Обязательные задачи* нужно сделать для того, чтобы проверить, что вы действительно усвоили материал модуля. Сдайте их на проверку.
#
# Удачи!

# %% [markdown]
# Цели практической работы:
#
#
# 1.   Потренироваться в обучении моделей деревьев решений.
# 2.   Потренироваться в обучении моделей случайного леса.
# 3.   Научиться оценивать качество моделей с помошью Accuracy и confusion matrix.
# 4.   Научиться увеличивать качество моделей с помощью тюнинга параметров.

# %% [markdown]
# Что оценивается:
#
# *   Все пункты и критерия приёмки задания выполнены.
# *   Удаление колонок по результатам feature_importance и определения типов производится с помощью кода, а не перечислением их вручную.

# %% [markdown]
# ## Обязательные задачи

# %% [markdown]
# ### Описание датасета:
# - `id`: идентификатор записи;
# - `is_manufacturer_name`: признак производителя автомобиля;
#
# - `region_*`: регион;
# - `x0_*`: тип топлива;
# - `manufacturer_*`: производитель;
# - `short_model_*`: сокращённая модель автомобиля;
# - `title_status_*`: статус;
# - `transmission_*`: коробка передач;
# - `state_*`: штат;
# - `age_category_*`: возрастная категория автомобиля;
#
# - `std_scaled_odometer`: количество пройденных миль (после стандартизации);
# - `year_std`: год выпуска (после стандартизации);
# - `lat_std`: широта (после стандартизации);
# - `long_std`: долгота (после стандартизации);
# - `odometer/price_std`: отношение стоимости к пробегу автомобиля (после стандартизации);
# - `desc_len_std`: количество символов в тексте объявления о продаже (после стандартизации);
# - `model_in_desc_std`: количество наименований модели автомобиля в тексте объявления о продаже (после стандартизации);
# - `model_len_std`: длина наименования автомобиля (после стандартизации);
# - `model_word_count_std`: количество слов в наименовании автомобиля (после стандартизации);
# - `month_std`: номер месяца размещения объявления о продаже автомобиля (после стандартизации);
# - `dayofweek_std`: день недели размещения объявления о продаже автомобиля (после стандартизации);
# - `diff_years_std`: количество лет между годом производства автомобиля и годом размещения объявления о продаже автомобиля (после стандартизации);
#
# - `price`: стоимость;
# - `price_category`: категория цены.

# %% [markdown]
# 0. *Подготовка базовой модели*
#
# Обучите простую модель классификации с помощью DecisionTreeClassifier на данных из датасета vehicles_dataset_prepared.csv. Для этого сделайте следующие шаги:
#
# 1. Обучите модель дерева решений с зафиксированным random_state на тренировочной выборке.
# 2. Сделайте предикт на тестовой выборке.
# 3. Замерьте точность на тестовой выборке и выведите матрицу ошибок.
# 4. Удалите фичи с нулевыми весами по feature_importance из тренировочной и тестовой выборок.
# 5. Заново обучите модель и измерьте качество.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('vehicles_dataset_prepared.csv')

df_prepared = df.copy()
df_prepared = df_prepared.drop(['price', 'odometer/price_std'], axis=1)

x = df_prepared.drop(['price_category'], axis=1)
y = df_prepared['price_category']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2)

# %%
clf = DecisionTreeClassifier() 
clf.fit(x_train, y_train)

predicted_test = clf.predict(x_test)

acc_sc = accuracy_score(y_test, predicted_test)
print(acc_sc)
print(confusion_matrix(y_test, predicted_test))
# Out:
# 0.6812196812196812
# [[716  44 232]
#  [ 50 684 213]
#  [150 231 566]]

# %%
f_imp_list = list(zip(x_train.columns, clf.feature_importances_))
f_imp_list.sort(key=lambda x: x[1], reverse=True)

f_imp_list
# Out:
# [('year_std', 0.22761329493483579),
#  ('std_scaled_odometer', 0.09231437463582423),
#  ('desc_len_std', 0.07336135833998345),
#  ('model_len_std', 0.0648953383167764),
#  ('lat_std', 0.04268807308763634),
#  ('id', 0.03482600900915182),
#  ('x0_diesel', 0.03281079695922175),
#  ('long_std', 0.03273887006754548),
#  ('dayofweek_std', 0.01863426380890079),
#  ('short_model_wrangler', 0.009347416862920127),
#  ('short_model_silverado', 0.009165078649929234),
#  ('diff_years_std', 0.008565054491552971),
#  ('manufacturer_kia', 0.008227917118715082),
#  ('manufacturer_ram', 0.007939577018771578),
#  ('manufacturer_volkswagen', 0.00779831030476771),
#  ('model_word_count_std', 0.006444051090641341),
#  ('manufacturer_hyundai', 0.006288994757076886),
#  ('short_model_tacoma', 0.005845703863382756),
#  ('short_model_f-150', 0.005561303145801309),
#  ('manufacturer_mercedes-benz', 0.0049030997873699125),
#  ('manufacturer_ford', 0.00479372084084888),
#  ('model_in_desc_std', 0.004659538341766213),
#  ('is_chevrolet', 0.004308199344164854),
#  ('short_model_cruze', 0.0042949271492165935),
#  ('short_model_Scion', 0.0036449968810592826),
#  ('state_or', 0.0036327750338708033),
#  ('short_model_focus', 0.0033342663476047378),
#  ('manufacturer_lexus', 0.003253492614118561),
#  ('manufacturer_mitsubishi', 0.0032146579932496432),
#  ('manufacturer_bmw', 0.0031418120988830865),
#  ('short_model_spark', 0.0030285299639919985),
#  ('manufacturer_chevrolet', 0.0029083626616308194),
#  ('manufacturer_jeep', 0.002586625969527159),
#  ('short_model_f150', 0.002577433804003677),
#  ('transmission_automatic', 0.0025743618185571533),
#  ('is_toyota', 0.0024121942238746513),
#  ('manufacturer_other', 0.0022949244431873174),
#  ('manufacturer_gmc', 0.002256500239716725),
#  ('manufacturer_honda', 0.002254587359239662),
#  ('title_status_salvage', 0.002120819603979953),
#  ('short_model_other', 0.0021167977486853022),
#  ('title_status_rebuilt', 0.00207620697743004),
#  ('short_model_tundra', 0.002021636023141631),
#  ('state_ca', 0.002009445550784632),
#  ('short_model_sentra', 0.0019930522314312907),
#  ('state_nj', 0.0019865056702791785),
#  ('short_model_prius', 0.0019611465928446904),
#  ('short_model_civic', 0.001937410257979661),
#  ('state_oh', 0.0019366203963073019),
#  ('short_model_acadia', 0.0018924717136745398),
#  ('short_model_2500', 0.001865777205112863),
#  ('short_model_sierra', 0.0018637850203779697),
#  ('short_model_escape', 0.0018403779585711732),
#  ('manufacturer_nissan', 0.0018153688793281673),
#  ('short_model_transit', 0.00177739193045436),
#  ('short_model_trax', 0.0017574055317582209),
#  ('short_model_1500', 0.0017463367873046104),
#  ('manufacturer_subaru', 0.0017205376722897175),
#  ('month_std', 0.00169415519353996),
#  ('short_model_escalade', 0.0016767578444655568),
#  ('state_ok', 0.001669851333477327),
#  ('short_model_f250', 0.0016560259415751577),
#  ('region_cincinnati', 0.0016250514682221032),
#  ('title_status_clean', 0.0016199930964312032),
#  ('short_model_tahoe', 0.0015929804970813285),
#  ('short_model_fj', 0.0015575510272948269),
#  ('short_model_4runner', 0.0015302473985663032),
#  ('manufacturer_pontiac', 0.0014967793687521325),
#  ('state_tx', 0.0014886886018331217),
#  ('short_model_versa', 0.0014806825333050604),
#  ('short_model_jetta', 0.0014789685101432475),
#  ('manufacturer_fiat', 0.0014576496153636093),
#  ('short_model_mustang', 0.0014377134353845342),
#  ('short_model_fusion', 0.0014207635089099645),
#  ('short_model_mx-5', 0.0014097090186792856),
#  ('transmission_manual', 0.001329154831356215),
#  ('short_model_explorer', 0.0013263945373491691),
#  ('region_hartford', 0.001302669268048927),
#  ('short_model_altima', 0.0012756665941595173),
#  ('short_model_f-250', 0.0012756175337723078),
#  ('short_model_fiesta', 0.0012682365764662543),
#  ('x0_other', 0.0012589619560510685),
#  ('short_model_x5', 0.0012493792477796918),
#  ('short_model_corolla', 0.0012482526207683584),
#  ('short_model_renegade', 0.001229025325835742),
#  ('region_central NJ', 0.0012261523800209783),
#  ('short_model_dart', 0.0012132419662200468),
#  ('region_denver', 0.0011869808171157585),
#  ('state_pa', 0.0011825896958558297),
#  ('state_tn', 0.0011760313682821568),
#  ('state_ri', 0.0011709129877551395),
#  ('region_nashville', 0.0011696747358421024),
#  ('manufacturer_rover', 0.001165120551672527),
#  ('short_model_500', 0.0011534008205171015),
#  ('manufacturer_mini', 0.0011464674259248613),
#  ('region_albany', 0.0011412409035800423),
#  ('short_model_ls', 0.0011365678624460594),
#  ('manufacturer_mazda', 0.0011353786116210748),
#  ('short_model_mazda3', 0.0011353615855769735),
#  ('region_atlanta', 0.0011299786431620922),
#  ('manufacturer_dodge', 0.0011278272184398353),
#  ('short_model_corvette', 0.001109236492724835),
#  ('short_model_grand', 0.0011076352455222569),
#  ('state_wv', 0.0011051401181954436),
#  ('short_model_suburban', 0.0010993032583161738),
#  ('state_md', 0.0010935980172412508),
#  ('short_model_highlander', 0.001093460813920458),
#  ('short_model_a5', 0.0010896148553322684),
#  ('region_fort collins / north CO', 0.001079888367304059),
#  ('short_model_verano', 0.0010676422104418503),
#  ('short_model_eurovan', 0.0010482087538270868),
#  ('state_ct', 0.0010466571774763649),
#  ('manufacturer_infiniti', 0.0010371056580444436),
#  ('short_model_fit', 0.0010268462466576946),
#  ('state_wa', 0.0010264723180486441),
#  ('region_kalispell', 0.0010011953564993984),
#  ('region_bowling green', 0.0009893477756249978),
#  ('state_id', 0.0009750789745452919),
#  ('transmission_other', 0.0009654675032808952),
#  ('state_ny', 0.0009654675032808952),
#  ('short_model_e350', 0.0009622030315876378),
#  ('short_model_gx', 0.0009585854621117722),
#  ('short_model_forte', 0.0009557270074832437),
#  ('region_raleigh / durham / CH', 0.0009392294996516499),
#  ('region_vermont', 0.0009336820314646125),
#  ('short_model_titan', 0.0009248755471469765),
#  ('manufacturer_toyota', 0.0009060541184636094),
#  ('short_model_sonic', 0.000899118443825459),
#  ('is_ford', 0.0008816521925565098),
#  ('state_co', 0.0008591750791586662),
#  ('short_model_super', 0.0008581016987691147),
#  ('region_chico', 0.0008523545661544789),
#  ('short_model_terrain', 0.0008461311706183186),
#  ('region_boise', 0.0008350976940115231),
#  ('short_model_f650', 0.0008313105689387735),
#  ('short_model_m3', 0.0008312400228764645),
#  ('region_portland', 0.00082650292626678),
#  ('state_nm', 0.0008248165115690046),
#  ('region_dallas / fort worth', 0.0008240281558890578),
#  ('short_model_hummer', 0.0008234527254535797),
#  ('manufacturer_porsche', 0.0008193960665298776),
#  ('short_model_lancer', 0.0008180231837813908),
#  ('region_statesboro', 0.0008161748408476296),
#  ('short_model_regal', 0.0008105295396054909),
#  ('region_bend', 0.0008087974417237464),
#  ('short_model_sonata', 0.0008052275904156318),
#  ('region_phoenix', 0.0008035623045811801),
#  ('short_model_legacy', 0.0008009233272083578),
#  ('short_model_c-max', 0.0007914585835137341),
#  ('region_SF bay area', 0.0007862123242430267),
#  ('short_model_sienna', 0.0007801251493535714),
#  ('short_model_sport', 0.0007790580084166607),
#  ('region_greensboro', 0.0007782113182790349),
#  ('region_corpus christi', 0.0007754666501778762),
#  ('region_milwaukee', 0.0007754307748451175),
#  ('region_tucson', 0.0007738593372451475),
#  ('region_harrisburg', 0.0007645422382624378),
#  ("region_spokane / coeur d'alene", 0.0007624807671719452),
#  ('region_el paso', 0.0007616476957277938),
#  ('region_south florida', 0.0007567444406681143),
#  ('region_cleveland', 0.0007563590517180602),
#  ('region_sacramento', 0.0007356192185604613),
#  ('short_model_avalanche', 0.000734517440482241),
#  ('short_model_atlas', 0.0007291642682121446),
#  ('region_elmira-corning', 0.0007180370779025784),
#  ('region_treasure coast', 0.0007168843401584767),
#  ('state_fl', 0.0007129606178074301),
#  ('region_fayetteville', 0.000710838711206813),
#  ('state_mn', 0.0007055339447052697),
#  ('short_model_f-350', 0.0007027573695966001),
#  ('short_model_impala', 0.0007003254807527501),
#  ('short_model_model', 0.0006910647957869136),
#  ('state_mi', 0.0006874977386000218),
#  ('short_model_avalon', 0.0006763577289467809),
#  ('region_reno / tahoe', 0.0006536689109491159),
#  ('short_model_cts', 0.0006535472329901443),
#  ('short_model_encore', 0.0006534235030624445),
#  ('short_model_impreza', 0.0006520382183827727),
#  ('state_va', 0.0006436118843584917),
#  ('region_charlotte', 0.0006339204928801363),
#  ('short_model_640', 0.0006303227521701193),
#  ('region_flint', 0.0006273475738716759),
#  ('region_western slope', 0.0006191017371612543),
#  ('region_bellingham', 0.0006136154635203608),
#  ('short_model_mirage', 0.0006060358946337632),
#  ('region_stockton', 0.0006043290853391962),
#  ('short_model_c-hr', 0.0005934179052825944),
#  ('short_model_rio', 0.000593277244220426),
#  ('region_bakersfield', 0.0005910419218347973),
#  ('short_model_colorado', 0.000583737031954916),
#  ('short_model_equinox', 0.0005741635897635113),
#  ('region_sioux falls / SE SD', 0.0005650635211322707),
#  ('region_chicago', 0.0005648164994760397),
#  ('short_model_a3', 0.000556181365972527),
#  ('state_ia', 0.0005529495700608768),
#  ('region_sarasota-bradenton', 0.0005380301763684925),
#  ('region_clarksville', 0.0005366284757136653),
#  ('short_model_camry', 0.0005350381819909552),
#  ('short_model_leaf', 0.0005323238502062799),
#  ('short_model_3500', 0.0005293598572066444),
#  ('region_knoxville', 0.0005126879998191627),
#  ('state_mt', 0.000504806031839177),
#  ('region_gold country', 0.00048061522926088474),
#  ('state_az', 0.00046416706888504565),
#  ('state_la', 0.00044573276889438984),
#  ('short_model_bus', 0.0004407036785897575),
#  ('state_ar', 0.00043749856092728664),
#  ('short_model_ecosport', 0.00043594477198176173),
#  ('short_model_cherokee', 0.0004315786942480723),
#  ('short_model_edge', 0.00043112316383780595),
#  ('short_model_accord', 0.00043108109431766814),
#  ('region_pueblo', 0.0004305669356130628),
#  ('region_akron / canton', 0.000430234855573449),
#  ('short_model_avenger', 0.0004285712070861377),
#  ('region_buffalo', 0.00042777637068445806),
#  ('region_orlando', 0.00042777637068445806),
#  ('short_model_e-class', 0.0004270337033742423),
#  ('region_pensacola', 0.0004265985955735604),
#  ('region_daytona beach', 0.00042415689848406083),
#  ('region_killeen / temple / ft hood', 0.0004233203668231616),
#  ('region_chattanooga', 0.0004218736123227409),
#  ('region_parkersburg-marietta', 0.0004218736123227409),
#  ('region_ft myers / SW florida', 0.00042141341320303227),
#  ('region_las cruces', 0.00042010555721153336),
#  ('region_susanville', 0.0004198448967504368),
#  ('short_model_excursion', 0.00041938859871025317),
#  ('region_pittsburgh', 0.00041938859871025317),
#  ('short_model_328d', 0.0004191944373219621),
#  ('region_albuquerque', 0.00041775036199654124),
#  ('region_wenatchee', 0.00041768708703096845),
#  ('short_model_Peterbilt', 0.00041736740189027933),
#  ('short_model_willys', 0.000416969876016052),
#  ('short_model_i3', 0.0004162806381190878),
#  ('region_long island', 0.00041540209361021674),
#  ('short_model_qx50', 0.0004138743277099762),
#  ('x0_gas', 0.0004137717871203838),
#  ('short_model_patriot', 0.0004137717871203838),
#  ('short_model_xc60', 0.0004128761299073583),
#  ('region_redding', 0.0004112896444594211),
#  ('region_odessa / midland', 0.0004110294399932693),
#  ('short_model_pilot', 0.00041082940996752687),
#  ('short_model_325is', 0.0004104291460691618),
#  ('short_model_e-450', 0.000409274267695162),
#  ('region_st joseph', 0.00040901324075680496),
#  ('short_model_cla', 0.00040846702061884027),
#  ('short_model_landcruiser', 0.0004078529195064253),
#  ('short_model_428', 0.0004078126881869342),
#  ('region_rockford', 0.00040707102943422427),
#  ('region_wichita falls', 0.00040707102943422427),
#  ('region_duluth / superior', 0.0004067254667996234),
#  ('short_model_gs350', 0.0004066975287996199),
#  ('state_dc', 0.00040636401997487363),
#  ('title_status_lien', 0.00040554704074075585),
#  ('short_model_ranger', 0.00040551323018048067),
#  ('region_missoula', 0.00040509126011785814),
#  ('state_nc', 0.00040509126011785814),
#  ('region_roanoke', 0.00040435965547985027),
#  ('region_sandusky', 0.00040425100532066806),
#  ('short_model_Xx', 0.000404245727652755),
#  ('short_model_q5', 0.00040418400085667647),
#  ('manufacturer_buick', 0.00040418400085667647),
#  ('short_model_lightning', 0.0004032606619680684),
#  ('short_model_e-350', 0.0004024887431871279),
#  ('region_yuba-sutter', 0.00040212471644137835),
#  ('short_model_utility', 0.0004010403475166797),
#  ('region_oklahoma city', 0.0004010403475166797),
#  ('short_model_f700', 0.00040099356393381543),
#  ('region_lansing', 0.0004007357791874529),
#  ('short_model_IC', 0.0003999980074321659),
#  ('short_model_xk8', 0.0003998671775182815),
#  ('short_model_xc40', 0.0003992240415949549),
#  ('short_model_750i', 0.00039762859619751895),
#  ('short_model_malibu', 0.0003975454425274274),
#  ('region_winston-salem', 0.00039726620534166654),
#  ('region_jersey shore', 0.00039672399050003884),
#  ('short_model_truck', 0.0003965163483759991),
#  ('state_ma', 0.0003964532847182861),
#  ('region_wichita', 0.0003959928131200797),
#  ('short_model_ssr', 0.00039540876081070646),
#  ('short_model_300zx', 0.00039430580750300014),
#  ('region_janesville', 0.0003942953497234116),
#  ('region_southern illinois', 0.00039320746263529424),
#  ('short_model_land', 0.0003921137005695634),
#  ('short_model_thunderbird', 0.0003910244958457564),
#  ('short_model_cayenne', 0.00039067149783109323),
#  ('short_model_yukon', 0.0003904608829695639),
#  ('region_skagit / island / SJI', 0.000390157969909074),
#  ('short_model_ml', 0.00038993982318043165),
#  ('region_lima / findlay', 0.00038990033786343844),
#  ('region_lincoln', 0.00038990033786343844),
#  ('region_texarkana', 0.00038990033786343844),
#  ('manufacturer_jaguar', 0.00038990033786343844),
#  ('region_corvallis/albany', 0.0003896748315951533),
#  ('region_chillicothe', 0.00038885965746526265),
#  ('region_topeka', 0.00038830890791297524),
#  ('region_richmond', 0.0003871236104655553),
#  ('short_model_coupe', 0.0003860929927920787),
#  ('short_model_camaro', 0.0003858415746564444),
#  ('short_model_tl', 0.00038512604801204975),
#  ('region_st louis, MO', 0.00038512604801204975),
#  ('short_model_qx80', 0.0003838289414403115),
#  ('short_model_sc', 0.0003822663210959866),
#  ('region_lawrence', 0.00038194318811112345),
#  ('region_north dakota', 0.00038194318811112345),
#  ('region_omaha / council bluffs', 0.00038194318811112345),
#  ('state_il', 0.0003816595107581001),
#  ('short_model_s8', 0.000380576153800992),
#  ('region_louisville', 0.00037995086359298683),
#  ('state_ks', 0.00037993296080527533),
#  ('short_model_s-class', 0.0003784050451253234),
#  ('region_zanesville / cambridge', 0.00037789455939682523),
#  ('region_merced', 0.0003777721015474101),
#  ('region_scottsbluff / panhandle', 0.00037736454068874447),
#  ('region_joplin', 0.0003765598324762223),
#  ('short_model_a4', 0.000374101896683683),
#  ('region_bemidji', 0.0003739013878295276),
#  ('short_model_650xi', 0.0003727898655202248),
#  ('short_model_odyssey', 0.0003721279516965029),
#  ('short_model_sequoia', 0.0003713336551080366),
#  ('short_model_trans', 0.0003713336551080366),
#  ('short_model_xc90', 0.0003710620844872325),
#  ('short_model_FORD*', 0.000368752250020685),
#  ('short_model_7', 0.0003679699004498407),
#  ('region_san marcos', 0.0003673754463182676),
#  ('short_model_genesis', 0.00036703400225941696),
#  ('region_fort wayne', 0.00036703400225941696),
#  ('region_laredo', 0.00036430842379518225),
#  ('manufacturer_lincoln', 0.00036354343856730896),
#  ('short_model_f-250sd', 0.00036190037189744824),
#  ('region_port huron', 0.00035892176801351894),
#  ('short_model_Town', 0.0003586022155043325),
#  ('region_maine', 0.00035768729723541156),
#  ('short_model_e250', 0.00035648030890371506),
#  ('short_model_f550', 0.00035648030890371506),
#  ('short_model_rogue', 0.0003548158319856945),
#  ('region_houston', 0.000354195178718435),
#  ('short_model_cc300', 0.0003524271899231246),
#  ('region_western KY', 0.0003499105596210346),
#  ('region_little rock', 0.00034770333160116166),
#  ('short_model_promaster', 0.00034562594052363403),
#  ('region_amarillo', 0.0003375760500982151),
#  ('region_detroit metro', 0.0003370389944621231),
#  ('short_model_3', 0.00033420028959723296),
#  ('short_model_rat', 0.00033420028959723296),
#  ('manufacturer_cadillac', 0.00033420028959723296),
#  ('region_boulder', 0.00032889552309568965),
#  ('short_model_insight', 0.00032182250109363174),
#  ('region_orange county', 0.0003169921446044217),
#  ('short_model_198.5', 0.0003087932500372093),
#  ('x0_electric', 0.00029706692408642925),
#  ('short_model_ASC', 0.00029706692408642925),
#  ('short_model_expedition', 0.00029706692408642925),
#  ('short_model_tsx', 0.00029706692408642925),
#  ('region_catskills', 0.00029706692408642925),
#  ('region_seattle-tacoma', 0.00029706692408642925),
#  ('manufacturer_audi', 0.00029706692408642925),
#  ('region_kansas city, MO', 0.0002822135778821079),
#  ('state_nh', 0.0002592584064754293),
#  ('short_model_a6', 0.00022280019306482196),
#  ('short_model_isf', 0.00022280019306482196),
#  ('short_model_rx', 0.00022280019306482196),
#  ('region_los angeles', 0.00022280019306482196),
#  ('region_san antonio', 0.00022280019306482196),
#  ('region_south coast', 0.000219997674913063),
#  ('region_new hampshire', 0.00021469836786246465),
#  ('region_brainerd', 0.000212190660061735),
#  ('region_santa fe / taos', 0.00021172312131922797),
#  ('region_tampa bay area', 0.00021122866703655993),
#  ('region_mohave county', 0.00020992679543694435),
#  ('region_bozeman', 0.00020863692265392426),
#  ('short_model_bronco', 0.0002073589016881906),
#  ('region_lexington', 0.0002062646481143545),
#  ('region_myrtle beach', 0.00020609258778476658),
#  ('region_inland empire', 0.00020478137963662944),
#  ('short_model_firebird', 0.0002035945131208793),
#  ('region_gainesville', 0.00020181387913629134),
#  ('short_model_juke', 0.00018707427079508237),
#  ('region_new orleans', 0.0001436205543973867),
#  ('region_eau claire', 0.00014226136933999327),
#  ('region_tulsa', 0.00014092138783912975),
#  ('region_columbia / jeff city', 0.00014008961510090148),
#  ('short_model_cr-v', 6.293382076831012e-05),
#  ('is_audi', 0.0),
#  ('x0_hybrid', 0.0),
#  ('short_model_-benz', 0.0),
#  ('short_model_1', 0.0),
#  ('short_model_124', 0.0),
#  ('short_model_128i', 0.0),
#  ('short_model_135i', 0.0),
#  ('short_model_163869', 0.0),
#  ('short_model_1928', 0.0),
#  ('short_model_1951', 0.0),
#  ('short_model_1954', 0.0),
#  ('short_model_1960s', 0.0),
#  ('short_model_1966', 0.0),
#  ('short_model_1968', 0.0),
#  ('short_model_1972', 0.0),
#  ('short_model_1977', 0.0),
#  ('short_model_1978', 0.0),
#  ('short_model_1988', 0.0),
#  ('short_model_1994', 0.0),
#  ('short_model_1999', 0.0),
#  ('short_model_2', 0.0),
#  ('short_model_200', 0.0),
#  ('short_model_2000', 0.0),
#  ('short_model_2002', 0.0),
#  ('short_model_2006', 0.0),
#  ('short_model_2007', 0.0),
#  ('short_model_2008', 0.0),
#  ('short_model_2009', 0.0),
#  ('short_model_2012', 0.0),
#  ('short_model_2015', 0.0),
#  ('short_model_2016', 0.0),
#  ('short_model_2017', 0.0),
#  ('short_model_2018', 0.0),
#  ('short_model_210', 0.0),
#  ('short_model_240', 0.0),
#  ('short_model_2500hd', 0.0),
#  ('short_model_280zx', 0.0),
#  ('short_model_3-series', 0.0),
#  ('short_model_3-window', 0.0),
#  ('short_model_3.2', 0.0),
#  ('short_model_300', 0.0),
#  ('short_model_300-series', 0.0),
#  ('short_model_300c', 0.0),
#  ('short_model_300s', 0.0),
#  ('short_model_3100', 0.0),
#  ('short_model_318i', 0.0),
#  ('short_model_320i', 0.0),
#  ('short_model_323i', 0.0),
#  ('short_model_325ci', 0.0),
#  ('short_model_325i', 0.0),
#  ('short_model_325xi', 0.0),
#  ('short_model_328', 0.0),
#  ('short_model_328ci', 0.0),
#  ('short_model_328i', 0.0),
#  ('short_model_328xi', 0.0),
#  ('short_model_330i', 0.0),
#  ('short_model_330xi', 0.0),
#  ('short_model_335i', 0.0),
#  ('short_model_335xi', 0.0),
#  ('short_model_350', 0.0),
#  ('short_model_3500hd', 0.0),
#  ('short_model_350z', 0.0),
#  ('short_model_370z', 0.0),
#  ('short_model_380sl', 0.0),
#  ('short_model_3i', 0.0),
#  ('short_model_4', 0.0),
#  ('short_model_4-runner', 0.0),
#  ('short_model_430i', 0.0),
#  ('short_model_435i', 0.0),
#  ('short_model_440xi', 0.0),
#  ('short_model_4500', 0.0),
#  ('short_model_4x4', 0.0),
#  ('short_model_5', 0.0),
#  ('short_model_5-series', 0.0),
#  ('short_model_50', 0.0),
#  ('short_model_500c', 0.0),
#  ('short_model_500l', 0.0),
#  ('short_model_500x', 0.0),
#  ('short_model_525i', 0.0),
#  ('short_model_528i', 0.0),
#  ('short_model_528xi', 0.0),
#  ('short_model_530', 0.0),
#  ('short_model_530i', 0.0),
#  ('short_model_535i', 0.0),
#  ('short_model_535xi', 0.0),
#  ('short_model_540i', 0.0),
#  ('short_model_545i', 0.0),
#  ('short_model_5500', 0.0),
#  ('short_model_5500hd', 0.0),
#  ('short_model_550i', 0.0),
#  ('short_model_5th', 0.0),
#  ('short_model_6', 0.0),
#  ('short_model_645ci', 0.0),
#  ('short_model_650i', 0.0),
#  ('short_model_750', 0.0),
#  ('short_model_750xi', 0.0),
#  ('short_model_86', 0.0),
#  ('short_model_911', 0.0),
#  ('short_model_914', 0.0),
#  ('short_model_928', 0.0),
#  ('short_model_944', 0.0),
#  ('short_model_ACURA*', 0.0),
#  ('short_model_ALL', 0.0),
#  ('short_model_AM', 0.0),
#  ('short_model_AMC', 0.0),
#  ('short_model_Acuarea', 0.0),
#  ('short_model_American', 0.0),
#  ('short_model_BUY', 0.0),
#  ('short_model_Bentley', 0.0),
#  ('short_model_Blue', 0.0),
#  ('short_model_Buicks', 0.0),
#  ('short_model_C', 0.0),
#  ('short_model_CHEVORLET', 0.0),
#  ('short_model_CLICK', 0.0),
#  ('short_model_Champion', 0.0),
#  ('short_model_Chevey', 0.0),
#  ('short_model_Chevorlet', 0.0),
#  ('short_model_Comanche', 0.0),
#  ('short_model_Comet', 0.0),
#  ('short_model_D7FH173552', 0.0),
#  ('short_model_DODGE1500', 0.0),
#  ('short_model_Diahatsu', 0.0),
#  ('short_model_E46', 0.0),
#  ('short_model_EASY', 0.0),
#  ('short_model_Eagle', 0.0),
#  ('short_model_Emergency', 0.0),
#  ('short_model_F-250', 0.0),
#  ('short_model_F250', 0.0),
#  ('short_model_FORD/RANGER', 0.0),
#  ('short_model_FREIGHTLINER', 0.0),
#  ('short_model_FRRV', 0.0),
#  ('short_model_Flexible', 0.0),
#  ('short_model_FordE350', 0.0),
#  ('short_model_Freightliner', 0.0),
#  ('short_model_Frtlner', 0.0),
#  ('short_model_GCM', 0.0),
#  ('short_model_GEHL', 0.0),
#  ('short_model_GMC,', 0.0),
#  ('short_model_GMX', 0.0),
#  ('short_model_GRAND', 0.0),
#  ('short_model_GULF', 0.0),
#  ('short_model_Genesis', 0.0),
#  ('short_model_Gx', 0.0),
#  ('short_model_HINO', 0.0),
#  ('short_model_HUMMER', 0.0),
#  ('short_model_Hino', 0.0),
#  ('short_model_Hobda', 0.0),
#  ('short_model_Hot', 0.0),
#  ('short_model_Hummer', 0.0),
#  ('short_model_INTERNATIONAL', 0.0),
#  ('short_model_International', 0.0),
#  ('short_model_Isizu', 0.0),
#  ('short_model_Isuzu', 0.0),
#  ('short_model_JM1BK32F871604924', 0.0),
#  ('short_model_Janesville', 0.0),
#  ('short_model_Jauguar', 0.0),
#  ('short_model_Jayco', 0.0),
#  ('short_model_Kaiser', 0.0),
#  ('short_model_Lotus', 0.0),
#  ('short_model_MASERATI', 0.0),
#  ('short_model_MERCUTY', 0.0),
#  ('short_model_MERDECES', 0.0),
#  ('short_model_MGB', 0.0),
#  ('short_model_MITUSBISHI', 0.0),
#  ('short_model_MV-1', 0.0),
#  ('short_model_Maserati', 0.0),
#  ('short_model_Minin', 0.0),
#  ('short_model_Nascar', 0.0),
#  ('short_model_OLDSMOBILE', 0.0),
#  ('short_model_PLYMOUTH', 0.0),
#  ('short_model_PROGRAMS', 0.0),
#  ('short_model_Pierce', 0.0),
#  ('short_model_Plymouth', 0.0),
#  ('short_model_QX', 0.0),
#  ('short_model_S60', 0.0),
#  ('short_model_SCION', 0.0),
#  ('short_model_SL', 0.0),
#  ('short_model_Saab', 0.0),
#  ('short_model_Sea', 0.0),
#  ('short_model_Sterling', 0.0),
#  ('short_model_Studebaker', 0.0),
#  ('short_model_Suzuki', 0.0),
#  ('short_model_THOMAS', 0.0),
#  ('short_model_Thomas', 0.0),
#  ('short_model_Triumph', 0.0),
#  ('short_model_Voltswagon', 0.0),
#  ('short_model_a-class', 0.0),
#  ('short_model_a3,', 0.0),
#  ('short_model_a7', 0.0),
#  ('short_model_a8', 0.0),
#  ('short_model_accent', 0.0),
#  ('short_model_all', 0.0),
#  ('short_model_allante', 0.0),
#  ('short_model_allroad', 0.0),
#  ('short_model_am', 0.0),
#  ('short_model_amc', 0.0),
#  ('short_model_arcadia', 0.0),
#  ('short_model_armada', 0.0),
#  ('short_model_arteon', 0.0),
#  ('short_model_ascent', 0.0),
#  ('short_model_aspen', 0.0),
#  ('short_model_astra', 0.0),
#  ('short_model_astro', 0.0),
#  ('short_model_ats', 0.0),
#  ('short_model_aura', 0.0),
#  ('short_model_autobiography', 0.0),
#  ('short_model_avanger', 0.0),
#  ('short_model_aveo', 0.0),
#  ('short_model_aviator', 0.0),
#  ('short_model_azera', 0.0),
#  ('short_model_aztek', 0.0),
#  ('short_model_b-class', 0.0),
#  ('short_model_b-series', 0.0),
#  ('short_model_b2200', 0.0),
#  ('short_model_b2300', 0.0),
#  ('short_model_b2600i', 0.0),
#  ('short_model_baja', 0.0),
#  ('short_model_beetle', 0.0),
#  ('short_model_bel', 0.0),
#  ('short_model_belair', 0.0),
#  ('short_model_benz', 0.0),
#  ('short_model_blackwood', 0.0),
#  ('short_model_blazer', 0.0),
#  ('short_model_blue', 0.0),
#  ('short_model_bolt', 0.0),
#  ('short_model_bonanza', 0.0),
#  ('short_model_bonneville', 0.0),
#  ('short_model_boxster', 0.0),
#  ('short_model_brz', 0.0),
#  ('short_model_bug', 0.0),
#  ('short_model_c', 0.0),
#  ('short_model_c-10', 0.0),
#  ('short_model_c-7500', 0.0),
#  ('short_model_c-class', 0.0),
#  ('short_model_c/k', 0.0),
#  ('short_model_c10', 0.0),
#  ('short_model_c250', 0.0),
#  ('short_model_c280', 0.0),
#  ('short_model_c30', 0.0),
#  ('short_model_c300', 0.0),
#  ('short_model_c4500', 0.0),
#  ('short_model_c5500', 0.0),
#  ('short_model_c60', 0.0),
#  ('short_model_c6500', 0.0),
#  ('short_model_c70', 0.0),
#  ('short_model_c8500', 0.0),
#  ('short_model_cabellero', 0.0),
#  ('short_model_cabrio', 0.0),
#  ('short_model_caddilac', 0.0),
#  ('short_model_cadenza', 0.0),
#  ('short_model_caliber', 0.0),
#  ('short_model_camary', 0.0),
#  ('short_model_camero', 0.0),
#  ('short_model_canyon', 0.0),
#  ('short_model_capri', 0.0),
#  ('short_model_caprice', 0.0),
#  ('short_model_captiva', 0.0),
#  ('short_model_caravan', 0.0),
#  ('short_model_caravan/grand', 0.0),
#  ('short_model_cargo', 0.0),
#  ('short_model_cascada', 0.0),
#  ('short_model_cavalier', 0.0),
#  ('short_model_cayman', 0.0),
#  ('short_model_cc', 0.0),
#  ('short_model_cc4500', 0.0),
#  ('short_model_century', 0.0),
#  ('short_model_certified', 0.0),
#  ('short_model_challenger', 0.0),
#  ('short_model_charger', 0.0),
#  ('short_model_chevelle', 0.0),
#  ('short_model_chevorlet', 0.0),
#  ('short_model_chryler', 0.0),
#  ('short_model_chysler', 0.0),
#  ('short_model_city', 0.0),
#  ('short_model_cj-5', 0.0),
#  ('short_model_cj2a', 0.0),
#  ('short_model_cj5', 0.0),
#  ('short_model_cj7', 0.0),
#  ('short_model_cj8', 0.0),
#  ('short_model_cl-class', 0.0),
#  ('short_model_cla-class', 0.0),
#  ('short_model_clarity', 0.0),
#  ('short_model_classic', 0.0),
#  ('short_model_classuc', 0.0),
#  ('short_model_clk', 0.0),
#  ('short_model_clk-class', 0.0),
#  ('short_model_clk350', 0.0),
#  ('short_model_cls-class', 0.0),
#  ('short_model_cls550', 0.0),
#  ('short_model_clubman', 0.0),
#  ('short_model_cmax', 0.0),
#  ('short_model_cobalt', 0.0),
#  ('short_model_colbalt', 0.0),
#  ('short_model_comet', 0.0),
#  ('short_model_commander', 0.0),
#  ('short_model_compass', 0.0),
#  ('short_model_concorde', 0.0),
#  ('short_model_conquest', 0.0),
#  ('short_model_continental', 0.0),
#  ('short_model_convertible', 0.0),
#  ('short_model_cooper', 0.0),
#  ('short_model_corsair', 0.0),
#  ('short_model_cougar', 0.0),
#  ('short_model_country', 0.0),
#  ('short_model_countryman', 0.0),
#  ('short_model_crew', 0.0),
#  ('short_model_crossfire', 0.0),
#  ('short_model_crosstour', 0.0),
#  ('short_model_crosstrek', 0.0),
#  ('short_model_crown', 0.0),
#  ('short_model_crv', 0.0),
#  ('short_model_crz', 0.0),
#  ('short_model_ct', 0.0),
#  ('short_model_ct4', 0.0),
#  ('short_model_ct5', 0.0),
#  ('short_model_ct6', 0.0),
#  ('short_model_cts-v', 0.0),
#  ('short_model_cts4', 0.0),
#  ('short_model_cube', 0.0),
#  ('short_model_cvr', 0.0),
#  ('short_model_cx-3', 0.0),
#  ('short_model_cx-5', 0.0),
#  ('short_model_cx-7', 0.0),
#  ('short_model_cx-9', 0.0),
#  ('short_model_cx7', 0.0),
#  ('short_model_cx9', 0.0),
#  ('short_model_d50', 0.0),
#  ('short_model_dakota', 0.0),
#  ('short_model_davidson', 0.0),
#  ('short_model_dealer*', 0.0),
#  ('short_model_defender', 0.0),
#  ('short_model_deisel', 0.0),
#  ('short_model_deluxe', 0.0),
#  ('short_model_denali', 0.0),
#  ('short_model_deville', 0.0),
#  ('short_model_diesel', 0.0),
#  ('short_model_discovery', 0.0),
#  ('short_model_dts', 0.0),
#  ('short_model_dump', 0.0),
#  ('short_model_duramax', 0.0),
#  ('short_model_durango', 0.0),
#  ('short_model_durangon', 0.0),
#  ('short_model_e', 0.0),
#  ('short_model_e-150', 0.0),
#  ('short_model_e-250', 0.0),
#  ('short_model_e-golf', 0.0),
#  ('short_model_e-pace', 0.0),
#  ('short_model_e-series', 0.0),
#  ('short_model_e150', 0.0),
#  ('short_model_e320', 0.0),
#  ('short_model_e450', 0.0),
#  ('short_model_e46', 0.0),
#  ('short_model_e500', 0.0),
#  ('short_model_echo', 0.0),
#  ('short_model_eclipse', 0.0),
#  ('short_model_econoline', 0.0),
#  ('short_model_el', 0.0),
#  ('short_model_elantra', 0.0),
#  ('short_model_elcamino', 0.0),
#  ('short_model_eldorado', 0.0),
#  ('short_model_element', 0.0),
#  ('short_model_enclave', 0.0),
#  ('short_model_endeavor', 0.0),
#  ('short_model_envision', 0.0),
#  ('short_model_envoy', 0.0),
#  ('short_model_eos', 0.0),
#  ('short_model_eqinox', 0.0),
#  ('short_model_es', 0.0),
#  ('short_model_es300', 0.0),
#  ('short_model_es330', 0.0),
#  ('short_model_es350', 0.0),
#  ('short_model_escape-se,', 0.0),
#  ('short_model_escort', 0.0),
#  ('short_model_evoque', 0.0),
#  ('short_model_express', 0.0),
#  ('short_model_f', 0.0),
#  ('short_model_f-100', 0.0),
#  ('short_model_f-350sd', 0.0),
#  ('short_model_f-450', 0.0),
#  ('short_model_f-450sd', 0.0),
#  ('short_model_f-550', 0.0),
#  ('short_model_f-650', 0.0),
#  ('short_model_f-750', 0.0),
#  ('short_model_f-pace', 0.0),
#  ('short_model_f-type', 0.0),
#  ('short_model_f1', 0.0),
#  ('short_model_f100', 0.0),
#  ('short_model_f350', 0.0),
#  ('short_model_f450', 0.0),
#  ('short_model_f450sd', 0.0),
#  ('short_model_f50', 0.0),
#  ('short_model_f600', 0.0),
#  ('short_model_f750', 0.0),
#  ('short_model_falcon', 0.0),
#  ('short_model_fe', 0.0),
#  ('short_model_fiero', 0.0),
#  ('short_model_five', 0.0),
#  ('short_model_fj40', 0.0),
#  ('short_model_fleetmaster', 0.0),
#  ('short_model_fleetwood', 0.0),
#  ('short_model_flex', 0.0),
#  ('short_model_fords', 0.0),
#  ('short_model_forester', 0.0),
#  ('short_model_forte5', 0.0),
#  ('short_model_foxbody', 0.0),
#  ('short_model_freestar', 0.0),
#  ('short_model_freestyle', 0.0),
#  ('short_model_freightliner', 0.0),
#  ('short_model_frontier', 0.0),
#  ('short_model_fuso', 0.0),
#  ('short_model_fx35', 0.0),
#  ('short_model_fx45', 0.0),
#  ('short_model_g', 0.0),
#  ('short_model_g-class', 0.0),
#  ('short_model_g.', 0.0),
#  ('short_model_g20', 0.0),
#  ('short_model_g30', 0.0),
#  ('short_model_g35', 0.0),
#  ('short_model_g35x', 0.0),
#  ('short_model_g37', 0.0),
#  ('short_model_g37s', 0.0),
#  ('short_model_g37x', 0.0),
#  ('short_model_g4500', 0.0),
#  ('short_model_g5', 0.0),
#  ('short_model_g6', 0.0),
#  ('short_model_g8', 0.0),
#  ('short_model_galant', 0.0),
#  ('short_model_ghia', 0.0),
#  ('short_model_gl', 0.0),
#  ('short_model_gl-class', 0.0),
#  ('short_model_gl450', 0.0),
#  ('short_model_gla', 0.0),
#  ('short_model_gla-class', 0.0),
#  ('short_model_gladiator', 0.0),
#  ('short_model_glc', 0.0),
#  ('short_model_glc-class', 0.0),
#  ('short_model_gle', 0.0),
#  ('short_model_gle-class', 0.0),
#  ('short_model_glk', 0.0),
#  ('short_model_glk-class', 0.0),
#  ('short_model_glk350', 0.0),
#  ('short_model_gls', 0.0),
#  ('short_model_gmc/chev', 0.0),
#  ('short_model_gmce', 0.0),
#  ('short_model_gmt-400', 0.0),
#  ('short_model_golf', 0.0),
#  ('short_model_gr', 0.0),
#  ('short_model_grandville', 0.0),
#  ('short_model_grumman', 0.0),
#  ('short_model_gs', 0.0),
#  ('short_model_gs430', 0.0),
#  ('short_model_gt', 0.0),
#  ('short_model_gt-r', 0.0),
#  ('short_model_gti', 0.0),
#  ('short_model_gto', 0.0),
#  ('short_model_gx460', 0.0),
#  ('short_model_gx470', 0.0),
#  ('short_model_hardbody', 0.0),
#  ('short_model_hardtop', 0.0),
#  ('short_model_hearse', 0.0),
#  ('short_model_hhr', 0.0),
#  ('short_model_hiace', 0.0),
#  ('short_model_high', 0.0),
#  ('short_model_hr-v', 0.0),
#  ('short_model_hse', 0.0),
#  ('short_model_hyndai', 0.0),
#  ('short_model_i-miev', 0.0),
#  ('short_model_i30', 0.0),
#  ('short_model_i35', 0.0),
#  ('short_model_ilx', 0.0),
#  ('short_model_international', 0.0),
#  ('short_model_ion', 0.0),
#  ('short_model_ioniq', 0.0),
#  ('short_model_is', 0.0),
#  ('short_model_is250', 0.0),
#  ('short_model_is300', 0.0),
#  ('short_model_isuzu', 0.0),
#  ('short_model_jeepster', 0.0),
#  ('short_model_jimmy', 0.0),
#  ('short_model_jouney', 0.0),
#  ('short_model_journey', 0.0),
#  ('short_model_jx35', 0.0),
#  ('short_model_k10', 0.0),
#  ('short_model_k20', 0.0),
#  ('short_model_k30', 0.0),
#  ('short_model_k5', 0.0),
#  ('short_model_k900', 0.0),
#  ('short_model_kicks', 0.0),
#  ('short_model_kodiak', 0.0),
#  ('short_model_l', 0.0),
#  ('short_model_l300', 0.0),
#  ('short_model_lacrosse', 0.0),
#  ('short_model_legend', 0.0),
#  ('short_model_lemans', 0.0),
#  ('short_model_lesabre', 0.0),
#  ('short_model_liberty', 0.0),
#  ('short_model_lifted', 0.0),
#  ('short_model_limousine', 0.0),
#  ('short_model_long', 0.0),
#  ('short_model_lr2', 0.0),
#  ('short_model_lr3', 0.0),
#  ('short_model_lr4', 0.0),
#  ('short_model_ltd', 0.0),
#  ('short_model_lucerne', 0.0),
#  ('short_model_lx', 0.0),
#  ('short_model_lx450', 0.0),
#  ('short_model_m', 0.0),
#  ('short_model_m-class', 0.0),
#  ('short_model_m35', 0.0),
#  ('short_model_m35s', 0.0),
#  ('short_model_m5', 0.0),
#  ('short_model_macan', 0.0),
#  ('short_model_magnum', 0.0),
#  ('short_model_mallinia', 0.0),
#  ('short_model_marineer,premier', 0.0),
#  ('short_model_mariner', 0.0),
#  ('short_model_mark', 0.0),
#  ('short_model_maserati', 0.0),
#  ('short_model_matrix', 0.0),
#  ('short_model_maxima', 0.0),
#  ('short_model_maximum', 0.0),
#  ('short_model_mazda2', 0.0),
#  ('short_model_mazda5', 0.0),
#  ('short_model_mazda6', 0.0),
#  ('short_model_mazda6i', 0.0),
#  ('short_model_md-x', 0.0),
#  ('short_model_mdx', 0.0),
#  ('short_model_mercades', 0.0),
#  ('short_model_mercedes-amg', 0.0),
#  ('short_model_metris', 0.0),
#  ('short_model_mg', 0.0),
#  ('short_model_miata', 0.0),
#  ('short_model_milan', 0.0),
#  ('short_model_mkc', 0.0),
#  ('short_model_mks', 0.0),
#  ('short_model_mkt', 0.0),
#  ('short_model_mkx', 0.0),
#  ('short_model_mkz', 0.0),
#  ('short_model_ml350', 0.0),
#  ('short_model_ml500', 0.0),
#  ('short_model_monte', 0.0),
#  ('short_model_montero', 0.0),
#  ('short_model_mountaineer', 0.0),
#  ('short_model_mpv', 0.0),
#  ('short_model_mr2', 0.0),
#  ('short_model_murano', 0.0),
#  ('short_model_nautilus', 0.0),
#  ('short_model_navigator', 0.0),
#  ('short_model_neon', 0.0),
#  ('short_model_new', 0.0),
#  ('short_model_newport', 0.0),
#  ('short_model_niro', 0.0),
#  ('short_model_nitro', 0.0),
#  ('short_model_nova', 0.0),
#  ('short_model_nv', 0.0),
#  ('short_model_nv1500', 0.0),
#  ('short_model_nv200', 0.0),
#  ('short_model_nv2500', 0.0),
#  ('short_model_nv2500hd', 0.0),
#  ('short_model_nx', 0.0),
#  ('short_model_nx300', 0.0),
#  ('short_model_oddyssey', 0.0),
#  ('short_model_oldsmobile', 0.0),
#  ('short_model_optima', 0.0),
#  ('short_model_optimia', 0.0),
#  ('short_model_outback', 0.0),
#  ('short_model_outlander', 0.0),
#  ('short_model_outlook', 0.0),
#  ('short_model_paceman', 0.0),
#  ('short_model_pacifica', 0.0),
#  ('short_model_panamera', 0.0),
#  ('short_model_panel', 0.0),
#  ('short_model_park', 0.0),
#  ('short_model_passat', 0.0),
#  ('short_model_passport', 0.0),
#  ('short_model_pathfinder', 0.0),
#  ('short_model_phaeton', 0.0),
#  ('short_model_pick', 0.0),
#  ('short_model_pickup', 0.0),
#  ('short_model_plymouth', 0.0),
#  ('short_model_pontaic', 0.0),
#  ('short_model_prelude', 0.0),
#  ('short_model_prizm', 0.0),
#  ('short_model_protege', 0.0),
#  ('short_model_pt', 0.0),
#  ('short_model_putback', 0.0),
#  ('short_model_q3', 0.0),
#  ('short_model_q50', 0.0),
#  ('short_model_q60', 0.0),
#  ('short_model_q7', 0.0),
#  ('short_model_q70', 0.0),
#  ('short_model_quattro', 0.0),
#  ('short_model_quest', 0.0),
#  ('short_model_qx56', 0.0),
#  ('short_model_qx60', 0.0),
#  ('short_model_qx70', 0.0),
#  ('short_model_r-class', 0.0),
#  ('short_model_r32', 0.0),
#  ('short_model_rabbit', 0.0),
#  ('short_model_rainier', 0.0),
#  ('short_model_ram1500', 0.0),
#  ('short_model_ram2500', 0.0),
#  ('short_model_ramcharger', 0.0),
#  ('short_model_range', 0.0),
#  ('short_model_rav', 0.0),
#  ('short_model_rav4', 0.0),
#  ('short_model_rc', 0.0),
#  ('short_model_rdx', 0.0),
#  ('short_model_reatta', 0.0),
#  ('short_model_rebel', 0.0),
#  ('short_model_rendezvous', 0.0),
#  ('short_model_replica', 0.0),
#  ('short_model_ridgeline', 0.0),
#  ('short_model_rivera', 0.0),
#  ('short_model_riviera', 0.0),
#  ('short_model_rl', 0.0),
#  ('short_model_rlx', 0.0),
#  ('short_model_roadmaster', 0.0),
#  ...]

# %%
to_delete = [col[0] for col in f_imp_list if col[1] == 0]
to_delete
# Out:
# ['is_audi',
#  'x0_hybrid',
#  'short_model_-benz',
#  'short_model_1',
#  'short_model_124',
#  'short_model_128i',
#  'short_model_135i',
#  'short_model_163869',
#  'short_model_1928',
#  'short_model_1951',
#  'short_model_1954',
#  'short_model_1960s',
#  'short_model_1966',
#  'short_model_1968',
#  'short_model_1972',
#  'short_model_1977',
#  'short_model_1978',
#  'short_model_1988',
#  'short_model_1994',
#  'short_model_1999',
#  'short_model_2',
#  'short_model_200',
#  'short_model_2000',
#  'short_model_2002',
#  'short_model_2006',
#  'short_model_2007',
#  'short_model_2008',
#  'short_model_2009',
#  'short_model_2012',
#  'short_model_2015',
#  'short_model_2016',
#  'short_model_2017',
#  'short_model_2018',
#  'short_model_210',
#  'short_model_240',
#  'short_model_2500hd',
#  'short_model_280zx',
#  'short_model_3-series',
#  'short_model_3-window',
#  'short_model_3.2',
#  'short_model_300',
#  'short_model_300-series',
#  'short_model_300c',
#  'short_model_300s',
#  'short_model_3100',
#  'short_model_318i',
#  'short_model_320i',
#  'short_model_323i',
#  'short_model_325ci',
#  'short_model_325i',
#  'short_model_325xi',
#  'short_model_328',
#  'short_model_328ci',
#  'short_model_328i',
#  'short_model_328xi',
#  'short_model_330i',
#  'short_model_330xi',
#  'short_model_335i',
#  'short_model_335xi',
#  'short_model_350',
#  'short_model_3500hd',
#  'short_model_350z',
#  'short_model_370z',
#  'short_model_380sl',
#  'short_model_3i',
#  'short_model_4',
#  'short_model_4-runner',
#  'short_model_430i',
#  'short_model_435i',
#  'short_model_440xi',
#  'short_model_4500',
#  'short_model_4x4',
#  'short_model_5',
#  'short_model_5-series',
#  'short_model_50',
#  'short_model_500c',
#  'short_model_500l',
#  'short_model_500x',
#  'short_model_525i',
#  'short_model_528i',
#  'short_model_528xi',
#  'short_model_530',
#  'short_model_530i',
#  'short_model_535i',
#  'short_model_535xi',
#  'short_model_540i',
#  'short_model_545i',
#  'short_model_5500',
#  'short_model_5500hd',
#  'short_model_550i',
#  'short_model_5th',
#  'short_model_6',
#  'short_model_645ci',
#  'short_model_650i',
#  'short_model_750',
#  'short_model_750xi',
#  'short_model_86',
#  'short_model_911',
#  'short_model_914',
#  'short_model_928',
#  'short_model_944',
#  'short_model_ACURA*',
#  'short_model_ALL',
#  'short_model_AM',
#  'short_model_AMC',
#  'short_model_Acuarea',
#  'short_model_American',
#  'short_model_BUY',
#  'short_model_Bentley',
#  'short_model_Blue',
#  'short_model_Buicks',
#  'short_model_C',
#  'short_model_CHEVORLET',
#  'short_model_CLICK',
#  'short_model_Champion',
#  'short_model_Chevey',
#  'short_model_Chevorlet',
#  'short_model_Comanche',
#  'short_model_Comet',
#  'short_model_D7FH173552',
#  'short_model_DODGE1500',
#  'short_model_Diahatsu',
#  'short_model_E46',
#  'short_model_EASY',
#  'short_model_Eagle',
#  'short_model_Emergency',
#  'short_model_F-250',
#  'short_model_F250',
#  'short_model_FORD/RANGER',
#  'short_model_FREIGHTLINER',
#  'short_model_FRRV',
#  'short_model_Flexible',
#  'short_model_FordE350',
#  'short_model_Freightliner',
#  'short_model_Frtlner',
#  'short_model_GCM',
#  'short_model_GEHL',
#  'short_model_GMC,',
#  'short_model_GMX',
#  'short_model_GRAND',
#  'short_model_GULF',
#  'short_model_Genesis',
#  'short_model_Gx',
#  'short_model_HINO',
#  'short_model_HUMMER',
#  'short_model_Hino',
#  'short_model_Hobda',
#  'short_model_Hot',
#  'short_model_Hummer',
#  'short_model_INTERNATIONAL',
#  'short_model_International',
#  'short_model_Isizu',
#  'short_model_Isuzu',
#  'short_model_JM1BK32F871604924',
#  'short_model_Janesville',
#  'short_model_Jauguar',
#  'short_model_Jayco',
#  'short_model_Kaiser',
#  'short_model_Lotus',
#  'short_model_MASERATI',
#  'short_model_MERCUTY',
#  'short_model_MERDECES',
#  'short_model_MGB',
#  'short_model_MITUSBISHI',
#  'short_model_MV-1',
#  'short_model_Maserati',
#  'short_model_Minin',
#  'short_model_Nascar',
#  'short_model_OLDSMOBILE',
#  'short_model_PLYMOUTH',
#  'short_model_PROGRAMS',
#  'short_model_Pierce',
#  'short_model_Plymouth',
#  'short_model_QX',
#  'short_model_S60',
#  'short_model_SCION',
#  'short_model_SL',
#  'short_model_Saab',
#  'short_model_Sea',
#  'short_model_Sterling',
#  'short_model_Studebaker',
#  'short_model_Suzuki',
#  'short_model_THOMAS',
#  'short_model_Thomas',
#  'short_model_Triumph',
#  'short_model_Voltswagon',
#  'short_model_a-class',
#  'short_model_a3,',
#  'short_model_a7',
#  'short_model_a8',
#  'short_model_accent',
#  'short_model_all',
#  'short_model_allante',
#  'short_model_allroad',
#  'short_model_am',
#  'short_model_amc',
#  'short_model_arcadia',
#  'short_model_armada',
#  'short_model_arteon',
#  'short_model_ascent',
#  'short_model_aspen',
#  'short_model_astra',
#  'short_model_astro',
#  'short_model_ats',
#  'short_model_aura',
#  'short_model_autobiography',
#  'short_model_avanger',
#  'short_model_aveo',
#  'short_model_aviator',
#  'short_model_azera',
#  'short_model_aztek',
#  'short_model_b-class',
#  'short_model_b-series',
#  'short_model_b2200',
#  'short_model_b2300',
#  'short_model_b2600i',
#  'short_model_baja',
#  'short_model_beetle',
#  'short_model_bel',
#  'short_model_belair',
#  'short_model_benz',
#  'short_model_blackwood',
#  'short_model_blazer',
#  'short_model_blue',
#  'short_model_bolt',
#  'short_model_bonanza',
#  'short_model_bonneville',
#  'short_model_boxster',
#  'short_model_brz',
#  'short_model_bug',
#  'short_model_c',
#  'short_model_c-10',
#  'short_model_c-7500',
#  'short_model_c-class',
#  'short_model_c/k',
#  'short_model_c10',
#  'short_model_c250',
#  'short_model_c280',
#  'short_model_c30',
#  'short_model_c300',
#  'short_model_c4500',
#  'short_model_c5500',
#  'short_model_c60',
#  'short_model_c6500',
#  'short_model_c70',
#  'short_model_c8500',
#  'short_model_cabellero',
#  'short_model_cabrio',
#  'short_model_caddilac',
#  'short_model_cadenza',
#  'short_model_caliber',
#  'short_model_camary',
#  'short_model_camero',
#  'short_model_canyon',
#  'short_model_capri',
#  'short_model_caprice',
#  'short_model_captiva',
#  'short_model_caravan',
#  'short_model_caravan/grand',
#  'short_model_cargo',
#  'short_model_cascada',
#  'short_model_cavalier',
#  'short_model_cayman',
#  'short_model_cc',
#  'short_model_cc4500',
#  'short_model_century',
#  'short_model_certified',
#  'short_model_challenger',
#  'short_model_charger',
#  'short_model_chevelle',
#  'short_model_chevorlet',
#  'short_model_chryler',
#  'short_model_chysler',
#  'short_model_city',
#  'short_model_cj-5',
#  'short_model_cj2a',
#  'short_model_cj5',
#  'short_model_cj7',
#  'short_model_cj8',
#  'short_model_cl-class',
#  'short_model_cla-class',
#  'short_model_clarity',
#  'short_model_classic',
#  'short_model_classuc',
#  'short_model_clk',
#  'short_model_clk-class',
#  'short_model_clk350',
#  'short_model_cls-class',
#  'short_model_cls550',
#  'short_model_clubman',
#  'short_model_cmax',
#  'short_model_cobalt',
#  'short_model_colbalt',
#  'short_model_comet',
#  'short_model_commander',
#  'short_model_compass',
#  'short_model_concorde',
#  'short_model_conquest',
#  'short_model_continental',
#  'short_model_convertible',
#  'short_model_cooper',
#  'short_model_corsair',
#  'short_model_cougar',
#  'short_model_country',
#  'short_model_countryman',
#  'short_model_crew',
#  'short_model_crossfire',
#  'short_model_crosstour',
#  'short_model_crosstrek',
#  'short_model_crown',
#  'short_model_crv',
#  'short_model_crz',
#  'short_model_ct',
#  'short_model_ct4',
#  'short_model_ct5',
#  'short_model_ct6',
#  'short_model_cts-v',
#  'short_model_cts4',
#  'short_model_cube',
#  'short_model_cvr',
#  'short_model_cx-3',
#  'short_model_cx-5',
#  'short_model_cx-7',
#  'short_model_cx-9',
#  'short_model_cx7',
#  'short_model_cx9',
#  'short_model_d50',
#  'short_model_dakota',
#  'short_model_davidson',
#  'short_model_dealer*',
#  'short_model_defender',
#  'short_model_deisel',
#  'short_model_deluxe',
#  'short_model_denali',
#  'short_model_deville',
#  'short_model_diesel',
#  'short_model_discovery',
#  'short_model_dts',
#  'short_model_dump',
#  'short_model_duramax',
#  'short_model_durango',
#  'short_model_durangon',
#  'short_model_e',
#  'short_model_e-150',
#  'short_model_e-250',
#  'short_model_e-golf',
#  'short_model_e-pace',
#  'short_model_e-series',
#  'short_model_e150',
#  'short_model_e320',
#  'short_model_e450',
#  'short_model_e46',
#  'short_model_e500',
#  'short_model_echo',
#  'short_model_eclipse',
#  'short_model_econoline',
#  'short_model_el',
#  'short_model_elantra',
#  'short_model_elcamino',
#  'short_model_eldorado',
#  'short_model_element',
#  'short_model_enclave',
#  'short_model_endeavor',
#  'short_model_envision',
#  'short_model_envoy',
#  'short_model_eos',
#  'short_model_eqinox',
#  'short_model_es',
#  'short_model_es300',
#  'short_model_es330',
#  'short_model_es350',
#  'short_model_escape-se,',
#  'short_model_escort',
#  'short_model_evoque',
#  'short_model_express',
#  'short_model_f',
#  'short_model_f-100',
#  'short_model_f-350sd',
#  'short_model_f-450',
#  'short_model_f-450sd',
#  'short_model_f-550',
#  'short_model_f-650',
#  'short_model_f-750',
#  'short_model_f-pace',
#  'short_model_f-type',
#  'short_model_f1',
#  'short_model_f100',
#  'short_model_f350',
#  'short_model_f450',
#  'short_model_f450sd',
#  'short_model_f50',
#  'short_model_f600',
#  'short_model_f750',
#  'short_model_falcon',
#  'short_model_fe',
#  'short_model_fiero',
#  'short_model_five',
#  'short_model_fj40',
#  'short_model_fleetmaster',
#  'short_model_fleetwood',
#  'short_model_flex',
#  'short_model_fords',
#  'short_model_forester',
#  'short_model_forte5',
#  'short_model_foxbody',
#  'short_model_freestar',
#  'short_model_freestyle',
#  'short_model_freightliner',
#  'short_model_frontier',
#  'short_model_fuso',
#  'short_model_fx35',
#  'short_model_fx45',
#  'short_model_g',
#  'short_model_g-class',
#  'short_model_g.',
#  'short_model_g20',
#  'short_model_g30',
#  'short_model_g35',
#  'short_model_g35x',
#  'short_model_g37',
#  'short_model_g37s',
#  'short_model_g37x',
#  'short_model_g4500',
#  'short_model_g5',
#  'short_model_g6',
#  'short_model_g8',
#  'short_model_galant',
#  'short_model_ghia',
#  'short_model_gl',
#  'short_model_gl-class',
#  'short_model_gl450',
#  'short_model_gla',
#  'short_model_gla-class',
#  'short_model_gladiator',
#  'short_model_glc',
#  'short_model_glc-class',
#  'short_model_gle',
#  'short_model_gle-class',
#  'short_model_glk',
#  'short_model_glk-class',
#  'short_model_glk350',
#  'short_model_gls',
#  'short_model_gmc/chev',
#  'short_model_gmce',
#  'short_model_gmt-400',
#  'short_model_golf',
#  'short_model_gr',
#  'short_model_grandville',
#  'short_model_grumman',
#  'short_model_gs',
#  'short_model_gs430',
#  'short_model_gt',
#  'short_model_gt-r',
#  'short_model_gti',
#  'short_model_gto',
#  'short_model_gx460',
#  'short_model_gx470',
#  'short_model_hardbody',
#  'short_model_hardtop',
#  'short_model_hearse',
#  'short_model_hhr',
#  'short_model_hiace',
#  'short_model_high',
#  'short_model_hr-v',
#  'short_model_hse',
#  'short_model_hyndai',
#  'short_model_i-miev',
#  'short_model_i30',
#  'short_model_i35',
#  'short_model_ilx',
#  'short_model_international',
#  'short_model_ion',
#  'short_model_ioniq',
#  'short_model_is',
#  'short_model_is250',
#  'short_model_is300',
#  'short_model_isuzu',
#  'short_model_jeepster',
#  'short_model_jimmy',
#  'short_model_jouney',
#  'short_model_journey',
#  'short_model_jx35',
#  'short_model_k10',
#  'short_model_k20',
#  'short_model_k30',
#  'short_model_k5',
#  'short_model_k900',
#  'short_model_kicks',
#  'short_model_kodiak',
#  'short_model_l',
#  'short_model_l300',
#  'short_model_lacrosse',
#  'short_model_legend',
#  'short_model_lemans',
#  'short_model_lesabre',
#  'short_model_liberty',
#  'short_model_lifted',
#  'short_model_limousine',
#  'short_model_long',
#  'short_model_lr2',
#  'short_model_lr3',
#  'short_model_lr4',
#  'short_model_ltd',
#  'short_model_lucerne',
#  'short_model_lx',
#  'short_model_lx450',
#  'short_model_m',
#  'short_model_m-class',
#  'short_model_m35',
#  'short_model_m35s',
#  'short_model_m5',
#  'short_model_macan',
#  'short_model_magnum',
#  'short_model_mallinia',
#  'short_model_marineer,premier',
#  'short_model_mariner',
#  'short_model_mark',
#  'short_model_maserati',
#  'short_model_matrix',
#  'short_model_maxima',
#  'short_model_maximum',
#  'short_model_mazda2',
#  'short_model_mazda5',
#  'short_model_mazda6',
#  'short_model_mazda6i',
#  'short_model_md-x',
#  'short_model_mdx',
#  'short_model_mercades',
#  'short_model_mercedes-amg',
#  'short_model_metris',
#  'short_model_mg',
#  'short_model_miata',
#  'short_model_milan',
#  'short_model_mkc',
#  'short_model_mks',
#  'short_model_mkt',
#  'short_model_mkx',
#  'short_model_mkz',
#  'short_model_ml350',
#  'short_model_ml500',
#  'short_model_monte',
#  'short_model_montero',
#  'short_model_mountaineer',
#  'short_model_mpv',
#  'short_model_mr2',
#  'short_model_murano',
#  'short_model_nautilus',
#  'short_model_navigator',
#  'short_model_neon',
#  'short_model_new',
#  'short_model_newport',
#  'short_model_niro',
#  'short_model_nitro',
#  'short_model_nova',
#  'short_model_nv',
#  'short_model_nv1500',
#  'short_model_nv200',
#  'short_model_nv2500',
#  'short_model_nv2500hd',
#  'short_model_nx',
#  'short_model_nx300',
#  'short_model_oddyssey',
#  'short_model_oldsmobile',
#  'short_model_optima',
#  'short_model_optimia',
#  'short_model_outback',
#  'short_model_outlander',
#  'short_model_outlook',
#  'short_model_paceman',
#  'short_model_pacifica',
#  'short_model_panamera',
#  'short_model_panel',
#  'short_model_park',
#  'short_model_passat',
#  'short_model_passport',
#  'short_model_pathfinder',
#  'short_model_phaeton',
#  'short_model_pick',
#  'short_model_pickup',
#  'short_model_plymouth',
#  'short_model_pontaic',
#  'short_model_prelude',
#  'short_model_prizm',
#  'short_model_protege',
#  'short_model_pt',
#  'short_model_putback',
#  'short_model_q3',
#  'short_model_q50',
#  'short_model_q60',
#  'short_model_q7',
#  'short_model_q70',
#  'short_model_quattro',
#  'short_model_quest',
#  'short_model_qx56',
#  'short_model_qx60',
#  'short_model_qx70',
#  'short_model_r-class',
#  'short_model_r32',
#  'short_model_rabbit',
#  'short_model_rainier',
#  'short_model_ram1500',
#  'short_model_ram2500',
#  'short_model_ramcharger',
#  'short_model_range',
#  'short_model_rav',
#  'short_model_rav4',
#  'short_model_rc',
#  'short_model_rdx',
#  'short_model_reatta',
#  'short_model_rebel',
#  'short_model_rendezvous',
#  'short_model_replica',
#  'short_model_ridgeline',
#  'short_model_rivera',
#  'short_model_riviera',
#  'short_model_rl',
#  'short_model_rlx',
#  'short_model_roadmaster',
#  'short_model_roadster',
#  'short_model_romeo',
#  'short_model_rondo',
#  'short_model_rouge',
#  'short_model_routan',
#  'short_model_rs',
#  'short_model_rsx',
#  'short_model_rx-8',
#  'short_model_rx300',
#  'short_model_rx330',
#  'short_model_rx350',
#  'short_model_rx400h',
#  'short_model_rx7',
#  'short_model_rx8',
#  'short_model_s',
#  'short_model_s-10',
#  'short_model_s/w',
#  'short_model_s10',
#  'short_model_s2000',
#  'short_model_s3',
#  'short_model_s320',
#  'short_model_s4',
#  'short_model_s40',
#  'short_model_s430',
#  'short_model_s5',
#  'short_model_s500',
#  'short_model_s6',
#  'short_model_s60',
#  'short_model_s7',
#  'short_model_s70',
#  'short_model_s90',
#  'short_model_saab',
#  'short_model_sable',
#  'short_model_santa',
#  'short_model_sante',
#  'short_model_savana',
#  'short_model_sc2',
#  'short_model_sc300',
#  'short_model_school',
#  'short_model_scion',
#  'short_model_sebring',
#  'short_model_sedan',
#  'short_model_sedona',
#  'short_model_seirra',
#  'short_model_sequioa',
#  'short_model_seville',
#  'short_model_shelby',
#  'short_model_sierra1500',
#  'short_model_sky',
#  'short_model_skylark',
#  'short_model_sl-class',
#  'short_model_sl2',
#  'short_model_sl500',
#  'short_model_sl55',
#  'short_model_sl550',
#  'short_model_slc',
#  'short_model_sle',
#  'short_model_slk',
#  'short_model_slk-class',
#  'short_model_slt',
#  'short_model_smart',
#  'short_model_solara',
#  'short_model_solstice',
#  'short_model_sonoma',
#  'short_model_sorento',
#  'short_model_sorrento',
#  'short_model_soul',
#  'short_model_soul+',
#  'short_model_spectra',
#  'short_model_sportage',
#  'short_model_sprinter',
#  'short_model_srx',
#  'short_model_srx-v6',
#  'short_model_srx4',
#  'short_model_srx~awesome',
#  'short_model_ss',
#  'short_model_starcraft',
#  'short_model_step-van',
#  'short_model_stinger',
#  'short_model_stratus',
#  'short_model_sts',
#  'short_model_studebaker',
#  'short_model_supra',
#  'short_model_suv',
#  'short_model_suzuki',
#  'short_model_svx',
#  'short_model_t',
#  'short_model_t-350',
#  'short_model_t-bucket',
#  'short_model_tarsus',
#  'short_model_taurus',
#  'short_model_tc5500',
#  'short_model_telluride',
#  'short_model_tercel',
#  'short_model_thing',
#  'short_model_thomas',
#  'short_model_thrift',
#  'short_model_tiguan',
#  'short_model_tlx',
#  'short_model_torrent',
#  'short_model_touareg',
#  'short_model_town',
#  'short_model_tracker',
#  'short_model_tractor',
#  'short_model_trailblazer',
#  'short_model_traverse',
#  'short_model_tribeca',
#  'short_model_tribute',
#  'short_model_triumph',
#  'short_model_tt',
#  'short_model_tucson',
#  'short_model_tudor',
#  'short_model_uplander',
#  'short_model_ux',
#  'short_model_v50',
#  'short_model_v6',
#  'short_model_v60',
#  'short_model_v90',
#  'short_model_van',
#  'short_model_vanagon',
#  'short_model_vandura',
#  'short_model_velar',
#  'short_model_veloster',
#  'short_model_venture',
#  'short_model_venza',
#  'short_model_veracruz',
#  'short_model_vibe',
#  'short_model_villager',
#  'short_model_vnl',
#  'short_model_volt',
#  'short_model_voyager',
#  'short_model_vtx1300c',
#  'short_model_vue',
#  'short_model_w350',
#  'short_model_windstar',
#  'short_model_wrx',
#  'short_model_x-3',
#  'short_model_x-type',
#  'short_model_x1',
#  'short_model_x2',
#  'short_model_x3',
#  'short_model_x4',
#  'short_model_x6',
#  'short_model_xc',
#  'short_model_xc70',
#  'short_model_xe',
#  'short_model_xf',
#  'short_model_xj',
#  'short_model_xj-series',
#  'short_model_xj8',
#  'short_model_xt4',
#  'short_model_xt5',
#  'short_model_xt6',
#  'short_model_xterra',
#  'short_model_xts',
#  'short_model_xv',
#  'short_model_yaris',
#  'short_model_z',
#  'short_model_z3',
#  'short_model_z4',
#  'short_model_zephyr',
#  'short_model_zx2',
#  'region_abilene',
#  'region_altoona-johnstown',
#  'region_ames',
#  'region_anchorage / mat-su',
#  'region_ann arbor',
#  'region_annapolis',
#  'region_appleton-oshkosh-FDL',
#  'region_asheville',
#  'region_ashtabula',
#  'region_athens',
#  'region_auburn',
#  'region_augusta',
#  'region_austin',
#  'region_baltimore',
#  'region_baton rouge',
#  'region_battle creek',
#  'region_beaumont / port arthur',
#  'region_billings',
#  'region_binghamton',
#  'region_birmingham',
#  'region_bismarck',
#  'region_bloomington',
#  'region_bloomington-normal',
#  'region_boone',
#  'region_boston',
#  'region_brownsville',
#  'region_brunswick',
#  'region_butte',
#  'region_cape cod / islands',
#  'region_cedar rapids',
#  'region_central louisiana',
#  'region_central michigan',
#  'region_champaign urbana',
#  'region_charleston',
#  'region_charlottesville',
#  'region_chautauqua',
#  'region_clovis / portales',
#  'region_college station',
#  'region_colorado springs',
#  'region_columbia',
#  'region_columbus',
#  'region_cumberland valley',
#  'region_danville',
#  'region_dayton / springfield',
#  'region_decatur',
#  'region_del rio / eagle pass',
#  'region_delaware',
#  'region_des moines',
#  'region_dothan',
#  'region_dubuque',
#  'region_east idaho',
#  'region_east oregon',
#  'region_eastern CO',
#  'region_eastern CT',
#  'region_eastern NC',
#  'region_eastern kentucky',
#  'region_eastern montana',
#  'region_eastern panhandle',
#  'region_eastern shore',
#  'region_elko',
#  'region_erie',
#  'region_eugene',
#  'region_evansville',
#  'region_fairbanks',
#  'region_fargo / moorhead',
#  'region_farmington',
#  'region_finger lakes',
#  'region_flagstaff / sedona',
#  'region_florence',
#  'region_florence / muscle shoals',
#  'region_florida keys',
#  'region_fort dodge',
#  'region_fort smith',
#  'region_frederick',
#  'region_fredericksburg',
#  'region_fresno / madera',
#  'region_gadsden-anniston',
#  'region_galveston',
#  'region_glens falls',
#  'region_grand forks',
#  'region_grand island',
#  'region_grand rapids',
#  'region_great falls',
#  'region_green bay',
#  'region_greenville / upstate',
#  'region_gulfport / biloxi',
#  'region_hanford-corcoran',
#  'region_harrisonburg',
#  'region_hattiesburg',
#  'region_hawaii',
#  'region_heartland florida',
#  'region_helena',
#  'region_hickory / lenoir',
#  'region_high rockies',
#  'region_hilton head',
#  'region_holland',
#  'region_houma',
#  'region_hudson valley',
#  'region_humboldt county',
#  'region_huntington-ashland',
#  'region_huntsville / decatur',
#  'region_imperial county',
#  'region_indianapolis',
#  'region_iowa city',
#  'region_ithaca',
#  'region_jackson',
#  'region_jacksonville',
#  'region_jonesboro',
#  'region_kalamazoo',
#  'region_kenai peninsula',
#  'region_kennewick-pasco-richland',
#  'region_kenosha-racine',
#  'region_kirksville',
#  'region_klamath falls',
#  'region_kokomo',
#  'region_la crosse',
#  'region_la salle co',
#  'region_lafayette',
#  'region_lafayette / west lafayette',
#  'region_lake charles',
#  'region_lake of the ozarks',
#  'region_lakeland',
#  'region_lancaster',
#  'region_las vegas',
#  'region_lawton',
#  'region_lehigh valley',
#  'region_lewiston / clarkston',
#  'region_logan',
#  'region_lubbock',
#  'region_lynchburg',
#  'region_macon / warner robins',
#  'region_madison',
#  'region_manhattan',
#  'region_mankato',
#  'region_mansfield',
#  'region_mason city',
#  'region_mattoon-charleston',
#  'region_mcallen / edinburg',
#  'region_meadville',
#  'region_medford-ashland',
#  'region_memphis',
#  'region_mendocino county',
#  'region_minneapolis / st paul',
#  'region_mobile',
#  'region_modesto',
#  'region_monroe',
#  'region_monterey bay',
#  'region_montgomery',
#  'region_morgantown',
#  'region_moses lake',
#  'region_muncie / anderson',
#  'region_muskegon',
#  'region_new haven',
#  'region_new river valley',
#  'region_new york city',
#  'region_norfolk / hampton roads',
#  'region_north central FL',
#  'region_north jersey',
#  'region_north mississippi',
#  'region_north platte',
#  'region_northeast SD',
#  'region_northern WI',
#  'region_northern michigan',
#  'region_northern panhandle',
#  'region_northwest CT',
#  'region_northwest GA',
#  'region_northwest KS',
#  'region_northwest OK',
#  'region_ocala',
#  'region_ogden-clearfield',
#  'region_okaloosa / walton',
#  'region_olympic peninsula',
#  'region_oneonta',
#  'region_oregon coast',
#  'region_outer banks',
#  'region_owensboro',
#  'region_palm springs',
#  'region_panama city',
#  'region_peoria',
#  'region_philadelphia',
#  'region_pierre / central SD',
#  'region_plattsburgh-adirondacks',
#  'region_poconos',
#  'region_potsdam-canton-massena',
#  'region_prescott',
#  'region_pullman / moscow',
#  'region_quad cities, IA/IL',
#  'region_rapid city / west SD',
#  'region_reading',
#  'region_rhode island',
#  'region_rochester',
#  'region_roseburg',
#  'region_roswell / carlsbad',
#  'region_saginaw-midland-baycity',
#  'region_salem',
#  'region_salina',
#  'region_salt lake city',
#  'region_san angelo',
#  'region_san diego',
#  'region_san luis obispo',
#  'region_santa barbara',
#  'region_santa maria',
#  'region_savannah / hinesville',
#  'region_scranton / wilkes-barre',
#  'region_sheboygan',
#  'region_show low',
#  'region_shreveport',
#  'region_sierra vista',
#  'region_sioux city',
#  'region_siskiyou county',
#  'region_south bend / michiana',
#  'region_south dakota',
#  'region_south jersey',
#  'region_southeast IA',
#  'region_southeast alaska',
#  'region_southeast missouri',
#  'region_southern WV',
#  'region_southern maryland',
#  'region_southwest KS',
#  'region_southwest MN',
#  ...]

# %%
x = df_prepared.drop(to_delete, axis=1)
x = df_prepared.drop(['price_category'], axis=1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2)
clf = DecisionTreeClassifier() 
clf.fit(x_train, y_train)

predicted_test = clf.predict(x_test)

print(f"new: {accuracy_score(y_test, predicted_test)}, old: {acc_sc}")
print(confusion_matrix(y_test, predicted_test))
# Out:
# new: 0.6898821898821899, old: 0.6812196812196812
# [[743  43 206]
#  [ 51 693 203]
#  [164 228 555]]

# %% [markdown]
# 1. *Подготовка модели случайного леса*
#
# Обучите простую модель классификации с помощью RandomForestClassifier. Для этого сделайте следующие шаги:
# 1. На новых урезанных семплах тренировочной и тестовой выборок обучите модель случайного леса с зафиксированным random_state=50.
#
# 2. Сделайте предикт и посчитайте точность модели и матрицу ошибок. Сравните с предыдущей моделью дерева решений. Есть ли случаи, когда модель из пункта 1 отрабатывает лучше, чем модель случайного леса?

# %%
from sklearn.ensemble import RandomForestClassifier

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=50)

rf_clf = RandomForestClassifier()
rf_clf.fit(x_train, y_train)

predicted_train_rf = rf_clf.predict(x_train)
predicted_test_rf = rf_clf.predict(x_test)

print(accuracy_score(y_test, predicted_test_rf))
print(confusion_matrix(y_test, predicted_test_rf))
# Out:
# 0.7598752598752598
# [[791  40 115]
#  [ 12 821 142]
#  [160 224 581]]

# %% [markdown]
# Эксперимента ради я попробовал без random_state несколько раз обучить модель и примерно в среднем её точность выше предыдущей модели процентов на 5-7 и ситуаций, когда дерево решений оказывалось лучше я не наблюдал, что вообще говоря неудивительно, поскольку случайный лес использует что-то в роде "роевого интеллекта", если так вообще можно выразиться

# %% [markdown]
# 2. *Тюнинг модели случайного леса*
#
# Увеличьте точность модели на тестовом датасете RandomForestClassifier c помощью тюнинга параметров.
#
# Параметры, которые можно настраивать для увеличения точности:
#
# ```
#     `bootstrap'
#     'max_depth'
#     'max_features'
#     'min_samples_leaf'
#     'min_samples_split'
#     'random_state'
#     'n_estimators'
#
# ```
#
#
#
# С описанием каждого из параметров можно ознакомиться в документации:
#
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
#
# Задание засчитывается, если значение метрики строго выше 0,76 на тестовом датасете.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=50)

rf_clf = RandomForestClassifier(n_estimators=100, max_depth=50, bootstrap=False)
rf_clf.fit(x_train, y_train)

predicted_train_rf = rf_clf.predict(x_train)
predicted_test_rf = rf_clf.predict(x_test)

print(accuracy_score(y_test, predicted_test_rf))
# Out:
# 0.7737352737352737

# %% [markdown]
# 3. *Анализ влияния фичей на модель*
#
# Во всех задачах до вы работали над подготовленным датасетом, где фичи были заранее извлечены из текстовых переменных, отскейлены и пропущены через One Hot Encoder. Сравним, какой была бы предсказательная способность модели, если бы мы использовали только сырые данные из исходного датасета. Для этого проделайте следующие шаги:
#
# 1. Загрузите датасет `vehicles_dataset_old.csv`.
# 2. Удалите из него переменную `price` и все строковые колонки. Дерево решений и случайный лес не умеют самостоятельно работать со строковыми значениями.
# 3. Сформируйте x_train и x_test так же, как они были сформированы в предыдущих заданиях.
# 4. Обучите свою лучшую модель случайного леса на новых данных и замерьте качество. Убедитесь, что оно ухудшилось.
# 5. Найдите три фичи, которые лучшим образом повлияли на предсказательную способность модели.

# %%
df_old = pd.read_csv('vehicles_dataset_old.csv')
df_nostr = df_old[["id", "price", "year", "odometer", "lat", "long"]]

x = df_nostr.drop(["price"], axis=1)
y = df_nostr["price"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=50)

rf_clf = RandomForestClassifier(n_estimators=100, max_depth=50, bootstrap=False)
rf_clf.fit(x_train, y_train)

predicted_train_rf = rf_clf.predict(x_train)
predicted_test_rf = rf_clf.predict(x_test)

print(accuracy_score(y_test, predicted_test_rf))
# Out:
# 0.08177408177408177

# %%
f_imp_list = list(zip(x_train.columns, rf_clf.feature_importances_))
f_imp_list.sort(key=lambda x: x[1], reverse=True)

f_imp_list[:3]
# Out:
# [('odometer', 0.23997405364022242),
#  ('id', 0.22774573785195767),
#  ('long', 0.20862210548250515)]

# %% [markdown]
# ей прям плохо
